# %% [markdown]
# # Text Classification Neural Network with PyTorch

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\vivek\Data science\Deep learning\1_foduu_contacts_message.csv")
df.head(10)
# Out:
#                                              message   labels
# 0  Hello,\n\nI Am Here For Providing Cheap and Pr...     spam
# 1  Hello,\n\nI Am Here For Providing Cheap and Pr...     spam
# 2  Hi,\n \nGet more leads for your business. Pay ...     spam
# 3  Hi \n\t\nI went through your website and we wo...  enquiry
# 4                                            sefgers      NaN
# 5                                       demo enquiry  enquiry
# 6                                       demo enquiry  enquiry
# 7                                     fsddfsdfsdfsda      NaN
# 8                                          qeqeqqeqe      NaN
# 9                                          wqsqdqdqd      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   message  1741 non-null   object
#  1   labels   105 non-null    object
# dtypes: object(2)
# memory usage: 27.6+ KB

# %%
df.isna().sum()
# Out:
# message      19
# labels     1655
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df[df.duplicated()]
# Out:
#                                              message   labels
# 1  Hello,\n\nI Am Here For Providing Cheap and Pr...     spam
# 6                                       demo enquiry  enquiry

# %%
df.drop_duplicates(inplace=True)

# %%
check_df=df

# %%
# label encoding

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df['label_encoded']=le.fit_transform(df['labels'])

print(le.classes_)
df.head()
# Out:
# ['enquiry' 'job' 'spam']
#                                               message   labels  label_encoded
# 0   Hello,\n\nI Am Here For Providing Cheap and Pr...     spam              2
# 2   Hi,\n \nGet more leads for your business. Pay ...     spam              2
# 3   Hi \n\t\nI went through your website and we wo...  enquiry              0
# 5                                        demo enquiry  enquiry              0
# 19  - for www.hpills.com-\n\nOpen cart\n\nThere ar...  enquiry              0

# %%
df['labels'].value_counts()
# Out:
# labels
# enquiry    58
# job        26
# spam       19
# Name: count, dtype: int64

# %%
# Convert text to numerical vector

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(max_features=500)
x=vectorizer.fit_transform(df['message']).toarray()
y=df['label_encoded']

# %%
x
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.14672734, 0.        ,
#         0.        ],
#        [0.        , 0.23243237, 0.23243237, ..., 0.15795752, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.36669898, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.08770386, 0.        ,
#         0.        ],
#        [0.04110025, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.05889119, 0.        ,
#         0.        ]])

# %%
# PyTorch Dataset
import torch
from torch.utils.data import DataLoader, Dataset

class text_dataset(Dataset):
    def __init__(self,x,y):
        self.x=torch.tensor(x,dtype=torch.float32)
        self.y=torch.tensor(y.values , dtype=torch.long)
    
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx] , self.y[idx]
    
dataset=text_dataset(x,y)
dataloader=DataLoader(dataset,batch_size=16, shuffle=True)

# %%
# Neural Network Model Design

import torch.nn as nn

class text_classifier(nn.Module):
    def __init__(self, input_size , hidden_size , num_clases):
        super(text_classifier,self).__init__()
        self.fc1=nn.Linear(input_size,hidden_size)
        self.relu=nn.ReLU()
        self.fc2=nn.Linear(hidden_size,num_clases)

    def forward(self , x):
        out=self.fc1(x)
        out=self.relu(out)
        out=self.fc2(out)

        return out

model=text_classifier(input_size=500 , hidden_size=128 , num_clases=3)

# %%
# Loss + Optimizer + Train Loop

import torch.optim.adam


criterion =nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.01)

num_epochs=20

for epoch in range(num_epochs):
    for batch_x , batch_y in dataloader:
        outputs=model(batch_x)
        loss=criterion(outputs,batch_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if (epoch+1)%5==0:
        print(f'Epoch : [{epoch+1}/{num_epochs}] , Loss : {loss.item():.4f}')
# Out:
# Epoch : [5/20] , Loss : 0.0064
# Epoch : [10/20] , Loss : 0.0002
# Epoch : [15/20] , Loss : 0.0014
# Epoch : [20/20] , Loss : 0.0006

# %%
#  Predict & Evaluate

with torch.no_grad():
    preds=model(torch.tensor(x,dtype=torch.float32))
    predicted=torch.argmax(preds,dim=1)
    accuracy = (predicted==torch.tensor(y.values)).float().mean()
    print(f'Accuracy : {accuracy.item():.4f}')
# Out:
# Accuracy : 1.0000

# %%
# Decode Labels

decoded_labels=le.inverse_transform(predicted.numpy())
print(decoded_labels[:10])
# Out:
# ['spam' 'spam' 'enquiry' 'enquiry' 'enquiry' 'enquiry' 'enquiry' 'spam'
#  'spam' 'spam']

# %% [markdown]
# # Check Model Works

# %%
def predict_message(msg):
    # 1. convert Message to TF-IDF vector
    msg_vector = vectorizer.transform([msg])
    
    # 2. Convert in Tensor
    msg_tensor = torch.tensor(msg_vector.toarray(), dtype=torch.float32)

    # 3. Take prediction to model
    with torch.no_grad():
        preds = model(msg_tensor)
        predicted_index = torch.argmax(preds, dim=1).item() 

    # 4. Label decode
    label = le.inverse_transform([predicted_index])[0]

    return label

# %%
for message in check_df['message']:
    print(f'{message}')
    print('----------------------')
    print(f'Prediction: {predict_message(message)}')
    print('----------------------')
# Out:
# Hello,
#
# I Am Here For Providing Cheap and Premium Paid Guest Poston High-Quality Websites.
#
# Why should you choose my service?
#
# - Your Post Will Be Published on time.
#
# - You Will Get Do-Follow Backlinks.
#
# - Your Post Will Be Permanent.
#
# - Your Post Will Be Google Indexed.
#
# - Provide unique content if needed.
#
#
# Here are the sample Sites:
#
# https://www.techtimes.com DA 84
# https://www.sciencetimes.com DA 65
# https://widetopics.world.edu DA 73
# https://techbeloved.com DA 64
# https://roseatehouselondon.com DA 39
#
# If you are interested then let me know if I can share our full list of sites.
# ----------------------
# Prediction: spam
# ----------------------
# Hi,
#
# Get more leads for your business. Pay us per lead. We generate leads for all types of business. Just reply us with your needs and business details. We will give the best leads.
#
# Let me know if we could have a quick demo on the same or schedule a meeting at you’re office?
#
# Start growing your business today.
#
# Thanks & Regards,
# Crystal Rose
# Sr. Demand Generation Specialist
# Leadraft International
# Call | WhatsApp: +91- 776-060-3754
# Ext: 080 4099 0002
#
#
#
# Marketing and Sales Office
# LeadRaft Private Limited
# 19/4, Skanda Arcade, 3rd Floor, Dinnur Main Road,
# RT Nagar, Bangalore, Karnataka 560032
# Phone- 080 4099 0002 /Email- marketing@leadraftinternational.com
#
#
# Please note all the email are sent by our third party marketing team of LeadRaft International
#
# ----------------------
# Prediction: spam
# ----------------------
# Hi
#
# I went through your website and we would love to
#
# collaborate with your team on a project.
#
# Please response to me on my email.
#
# ----------------------
# Prediction: enquiry
# ----------------------
# demo enquiry
# ----------------------
# Prediction: enquiry
# ----------------------
# - for www.hpills.com-
#
# Open cart
#
# There are few very important things for me before getting into the work
#
# 1- I need an exact detailed overview of
# A- no of hours required for each type of work
# (Please divide the work according the required time for it)
#
# B- charges required
#
# C- about transparency of work in terms of prepayment and post payment (as iam having a bad experience from a developer who has troubled me for time , money for which I have sued him )
#
# 2- please try to utilise the existing platform for the below mentioned future work.
#
# 1- existing platform use… and make it running by
# - 1-Shipping integration (I have registered with Delhivery and have its API) u can suggest me if u have any other.
# - 2-Sms api ( I have registered with mvayoo and have the API)
#  -3-Graphic changes. To do in it.
#
#
#
# 2- lab module—
# Pathway-
#
# customer—search vendor..then OTP verification .. vendor will get the map , execution— upload of lab report..
#  ( here according to area or according to vendor support has to be decided in MAP)
#
#  suggestions we can go with  Mobile app or website— whichever is more practical.. PERFECT.. economical
#
#
# 3- online consultation—
# Just video or text consultation ..with payment ..
# And platform for doctors to upload his details… etc
# (If dr could get his own name webpage in our platform)
#
#
# 4- banner designing..
#
# 5- seo -
# ----------------------
# Prediction: enquiry
# ----------------------
# Demo contact form
# ----------------------
# Prediction: enquiry
# ----------------------
# Demo test
# ----------------------
# Prediction: enquiry
# ----------------------
#
#   Hi
# We can help your website to get on first page of Google and increase the number of leads and sales you are getting from your website. Please email us back for full proposal.
#
# Best Regards
# Andy
# ----------------------
# Prediction: spam
# ----------------------
#  Hi
# We can help your website to get on first page of Google and increase the number of leads and sales you are getting from your website. Please email us back for full proposal.
#
# Best Regards
# Andy
# ----------------------
# Prediction: spam
# ----------------------
# We deliver an integrated portfolio of solutions and services reflecting a broad range of technology and business practices such as Website Design & Development, Mobile Website Optimization, ERP Solution, Social Media Marketing, Content writing and Analytics etc. We develop tailored software to meet your business needs.
#
#
#
# Our Industry insight and expertise has leaded us to structure our solutions in such a way that reduces operational cost, increases customer satisfaction and adds value to the deliverables.
#
# We can execute the Web Design & Development or Web Apps Development projects on a white label basis for you. Our aim is to be the best in service and as such we offer a premium service at very competitive prices.
#
# We offer effective services like:-
# • Responsive Web design
# • Web Portal development
# • E-commerce Web development
# • Web Apps development
# • Product development
# • Search Engine Optimization (SEO)
# • PPC (Pay per Click Campaign)
# • Social Media Optimization Marketing (SMO)
# • Logo Design
# • Flash Design
# • Graphic Designs
# * Software Development
#
# *Mobile application Development
#
#
# Please let me know your opinion or interest with further communication mode (Email / Phone call / Skype / Google hangout), then we can send you more details about package/action with special Offers.
# Looking for your reply and interest
#
#
#
# ----------------------
# Prediction: spam
# ----------------------
# Good morning and happy new year,
# i would like to help to start my project regarding my e commerce website.
# i would like to start 3 project this year.
# the 1 website are a special website for our security equipments and services, to add all our products with our partners products. cctv camera, alarms and others from their website.
# 2- we would like a special telecommunication website, to sell the internet via the website, satellite internet, mini sat , and rural internet who all customers can have access internet and sell our telecommunication equipments.
#
# 3- we will need an ecommerce unlimited products, ours own products, and it, security equipment and others.
# could we talk next monday at any time.
# thanks
# ----------------------
# Prediction: enquiry
# ----------------------
# Can Nehul Aggarwal .contact me for thewebsite
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#
# We’re IT leads provider from Noida, India. If you are looking for Web
#
# Design, Development or E commerce leads kindly get back to us and we
#
# will charge as mentioned below.
#
# Web Development INR 450 Per Lead
# Web Designing INR 350 Per Lead
# SEO INR 250 Per Lead
#
# Email: info@eacpl.net
# WhatsAPP: +91 9212464161
# ----------------------
# Prediction: spam
# ----------------------
# Hi,
#
# We can promote your website on google by doing SEO of your website at a very low cost of just $99 per month onwards.
#
# If you would like to know more about this, please send a quick email to us.
#
# Best
# Betty | Marketing Executive
# Skype: ranksindia
# ----------------------
# Prediction: spam
# ----------------------
# Hi together
# we are interested in doing following business idea in switzerland. (follow the link)
# https://www.josephine.com/
#
# we Need a cheap web developer that programs such a website inkl. seo possibility...
# we will do all the content in german (incl. bottoms and so on).
#
# what Price can you offer?
#
# thank you in  advance
# linda Grünenfelder
# ----------------------
# Prediction: enquiry
# ----------------------
# We are offering web hosting and other services with best customer care
# ----------------------
# Prediction: spam
# ----------------------
# Hello world,
#
# Below is a link to a few of the websites that have qualities we want to integrate into our own.
#
# https://www.yourhomesuite.com/
# www.airbnb.com
# https://www.corporatehousingbyowner.com/
# https://www.housestay.com/
# https://www.trulia.com/rent/
# https://www.zillow.com/
# https://www.vacasa.com/
#
# We want our website to have the following capabilities and qualities:
#
# 1.	This is a website for a Real Estate company based out of Santa Monica CA doing business all throughout los angeles so a design that is inviting and catches the attention of people looking to rent, long or short term and buy real estate.
# 2.	Data Integration; One of the pages and functions of the site is to populate all listing from “The MLS”; the mls is a database exclusive for realtors to list all of their properties and put them on the market; this is the same data base that websites like Zillow.com and trulia.com get most of their data. (real estate for sale, real estate for lease off market information of properties according to public records)
# 3.	Listing search : we want to divide our data into 3 categories:
# a.	Corporate housing / short term furnished units
# b.	Apartments for lease
# c.	Homes for sale
# 4.	Pages need to properly detail the information for each property or listing; beds baths, amenities, services, address, etc
# 5.	The website should be able to connect to social media accounts
# 6.	The website need to have a database of leads coming in; people that enter the site, view listings, and express and interest. Such database should be geared towards lead management
# 7.	Website should have the capability also for landlords or home owners to create an account on the website and upload their own listings; such listings should populate in the maps in additional to data extracted from the mls
# 8.	Website should be design in a way that it rank up higher on search engines such as google, yahoo, and bing
# 9.	We are looking for a long term relationship with a company that can help us grow and run an efficient operation.
#
# Please reach out to discuss further the timeline that it would take to create a website like this and the cost.
#
# Best,
#
# Jay
# Cozy Customer Support.
#
# Project Type: I am not sure
# Devices: Windows Phone, iPhone, Android
# Project Stage: Concept
# API Integration Required: Social Media, Cloud Storage, Payment Processor
# You will be asked to answer the following questions when submitting a proposal:
# Please send us information on work you have done for other companies ideally in the Real Estate industry
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Interested in an application for space to rent hourly, daily, and weekly please give me a call 818-744-2178.
# ----------------------
# Prediction: spam
# ----------------------
# I am looking for an ecommerce website get me the options and details you have
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello, I am reaching you to your company from a food production company in Greece, we are looking to start a new business venture creatin a multi restaurant platform where customers can choos the restaurant they want to order delivery from and place thier order and have the order print ourt to specific restaurant. We are looking, please let me know if you take on such projects so perhaps we can discus further.
# Thank you,
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi!
#
# We are a small e-commerce store, selling products online over eBay and Amazon. We have a large product catalogue and serve about 5000 customers daily. We want a web based back office system to be developed.  In summary, the system should be able to handle all the following things,
# 	Keep Inventory record.
# 	Keep Customer record.
# 	Manage transactions and sale records.
# 	A very specific order sorting process, that helps in printing different types of items on different kind of packing envelops.
# 	Manage picking and packing records by the workers (Also maintain timesheet).
# The system is supposed to web based and should be able to able 20-30 simultaneous users located at different locations.
# Please quote the project pricing and let me know if you need anything for me in support of the project. I can provide all the necessary documents and be the basic point of communication from the business side and me.
#
# ----------------------
# Prediction: enquiry
# ----------------------
# We are planning to start an ecommerce business. I would like to know whether foduu.com support us for developing and hosting the website.
# ----------------------
# Prediction: enquiry
# ----------------------
# i want website urgent plz contact asap
# ----------------------
# Prediction: enquiry
# ----------------------
# Need website design.
# one page - with logo and payment integration.
#
#
#
# Regards
# Shaker
#
# ----------------------
# Prediction: enquiry
# ----------------------
#
# I WANT TO HIRE PHP TEAM FOR A SOCIAL NETWORKING WEB APP THAT CONNECTS PEOPLE WITH SAME HOBBY. PLEASE LET ME KNOW FOLLOWING:
#
# 1. WHAT TEAM SIZE YOU CAN OFFER?
# 2. HOW SOON CAN YOU START?
# 3. WHAT IS THE PRICE BREAK DOWN STRUCTURE?
#
# Please don't give a call until I request you to call.
#
# ----------------------
# Prediction: spam
# ----------------------
# Hello there,
#
# I'm looking for a developer for a website, please give me a call back with a quote thank you.
#
# Roshan
# ----------------------
# Prediction: enquiry
# ----------------------
# Need to inquire about website development.
# ----------------------
# Prediction: enquiry
# ----------------------
# please contact me on whatsapp i need to create application of songs
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#
# We've recently started our film production company and we would like to have a simple landing page. Do you have any ready templates for it and what would be the price?
#
# Thanks for helping
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#
# I am looking for a web development team, who can develop websites/mobile apps/E-commerce websites based on my requirements. I am located in Germany and having few projects in pipeline.
#
# do you have capacity to develop my projects? We can talk.
# Please write me back.
#
# Thank you
# Regards,
# Yadav
# ----------------------
# Prediction: enquiry
# ----------------------
# I  already have a  functioning  website I just need to update  it with my new  business address.  I also to  fix  one of the forms that does not  route employment applications into my email inbox.  Please,  I need to know how much this will  cost. I do not  have too much money to spare. I am a one person business. Thanks, Henry Bate
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi Team, I am looking for an Android App development for my Grocery Business, it would be an E Comm type app, and my budget is less than Rs 100000.
# ----------------------
# Prediction: enquiry
# ----------------------
# Inquire for Website designing.
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi
#
# I am looking for website cms  e-commerce package.
#
# Best regards
# Yusuf
# ----------------------
# Prediction: enquiry
# ----------------------
# Need Web Development Service.
# ----------------------
# Prediction: enquiry
# ----------------------
# we want to create our buniness webside
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi I am looking to update and regenerate my website to the next level and get some serious SEO going. My site, www.withfriendslikeyou.com is a free to use and join consumer website. What could you do for me and at what costs?
# ----------------------
# Prediction: enquiry
# ----------------------
# Im looking for a web designer to create eye catching web site for me.
# ----------------------
# Prediction: enquiry
# ----------------------
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?What is Lorem Ipsum?
# What is Lorem Ipsum?What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?What is Lorem Ipsum?What is Lorem Ipsum?
# What is Lorem Ipsum?What is Lorem Ipsum?
# What is Lorem Ipsum?
# ----------------------
# Prediction: spam
# ----------------------
#
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# What is Lorem Ipsum?
# ----------------------
# Prediction: spam
# ----------------------
# hi i would like to if you can copy this site in its entirety. www.represent.com
# It has a shopify app installed which i will get a hold of. i need to know if you can do it. thank you
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello
#
# i want to build e commerce web site. when i get the web site is it possible that i add my self the product and price...etc.
#
# thanks
# ----------------------
# Prediction: enquiry
# ----------------------
# Build website and iOS application
#
# Skype is aspesite
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello,
#
# We are going to launch a Nepali national news website in Nepali language.
#
# We have the following:
# 1.     Domain name and space
#
# 2.     Basic layout of all pages (landing page, news detail page, and section news page)
#
# 3.     Basic logo and branding
#
#
# We need the following:
# 1.     Page header and footer design
#
# 2.     Menu bar design
#
# 3.     Brand based evaluation and redesign of existing page layouts (assuming we need redesign)
#
# 4.     Logo and branding redesign if needed based on header design
#
# 5.     Mobile and tablet responsive
#
# 6.     Search engine friendly design
#
# 7.     Link to social network sites
#
# 8.     Text zoom feature in news detail pages only.
#
# 9.     Night mode feature
#
# 10.  Option to add additional pages in future
#
#
# Questions:
#
# 1. Based on these information, can you give rough estimation on price?
#
# 2. Let me know if you can add night mode and text zoom features.
#
# 3. Please give time estimation to deploy the website.
#
# Hope to hear from you either way.
#
# Thank you,
#
# Mun Adhikari
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi
#  I went through your website and we would love to
# collabarte with your team on a project.
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#
# How much do you charge to design basic e commerce website ?
#
# Also what about SEO ?
#
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Good afternoon!
# I´m searching a partner for designing my webpage (suggested in WordPress).
# Please let me know If you are interested in more details!
# Thanks a lot!
# best regards,
# Stefan
# ----------------------
# Prediction: enquiry
# ----------------------
# i want make a ecommerce website so plz tell me full guideline
# ----------------------
# Prediction: enquiry
# ----------------------
# looking for website designer for my new project ASAP
# ----------------------
# Prediction: enquiry
# ----------------------
# i am looking a company web design with best rate  ,  pls   reply me ,
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello,
#
# I am a Sales Manager from Sneed Commerce looking for webdesigners to help me with a new project. I'm gonna offer a shipping service and need a custom form system with different factors (i.e. in case size of package is larger than x then use different shipping method etc.). as well as an automatic email system, where customers and my shipping agent get an email with a payment link and the price offer for the shipping. If this is something you are able to do, please contact with me.
#
# With regards,
#
# Mounteder Abdulrazag
# Sales Manager
# Sneed Commerce
# ----------------------
# Prediction: enquiry
# ----------------------
# I need a static web design quote for 7 pages website!
# Thanks,
# ----------------------
# Prediction: enquiry
# ----------------------
# Required web site & logo for our resort.
# ----------------------
# Prediction: enquiry
# ----------------------
# I need fixes to website I paid designer for who messed it up, www.radiancebio.com
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi, I am starting now a store online and would like help with my website. please write back also if u have another way to communicate let me know.  If u have WhatsApp add me on there.
# Kind regards, Asiya Adan
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello,
#
# I need to know if you can help me with a nice and elegant website for my start up business about "Solar Panels". I already have the domain, Sivana.solar and also I have the hosting, I can create my own emails too.
# Please let me know if you have experience with this kind of websites. Any idea is highly appreciated.
#
# Best Regards,
#
# Esteban
# ----------------------
# Prediction: enquiry
# ----------------------
# Requirement of one simple static website
# ----------------------
# Prediction: enquiry
# ----------------------
# Dear Sir/Madam,
#
# We want to enquire from you whether you can send us your company us a demo dispatch system software with user and driver app  or a detailed email which has details of all the products you manufacture. We can check and let you know if your Taxi dispatch system and apps will suit our requirement. We have a huge requirement and hope you will be able to meet our demands. We are in search of latest, fast and reliable with all the latest features.
#
# We shall place an order if we find it useful for our Taxi Firm.
# Your company has reputation in the industry and we are sure you can deliver products of high standards. We can discuss the pricing in our next meeting or emailing.
#
# You can send us a representative with the necessary information so that we can discuss and finalise the deal.
#
# We look forward to hear from you at the earliest
#
#
# Yours Sincerely,
# Shab
# ASAP CARS LTD
#
# ----------------------
# Prediction: enquiry
# ----------------------
# We are a Japanese Tech company and would like to build Global Corporate website and also landing pages.
#
# Requirements: Global corporate website design. Landing Page Development. Application UI redesign..
# For the global website approximately 15-20 pages.
# - Responsive
# - Flat design and the pages should load fast
# - The content should be updatable. i.e. We should be be able to change the content of the website without any development.
#
# Landing page requirement -
# Since landing pages and the contents are specific to the features of our product, the number of pages in Landing Page might differ. But on an average 2-3 LP in a month.
#
# Application UI -
# I think redesign of application UI is bit complicated and it will not just be like simple UI redesign, UI and the feature of the product are dependent on each other, proabably I might need to  explain the Application UI (both web and mobile version) details later on. I might need to show you the UI of the application and you will be able to understand issues.
#
# We don't need the domain name and server space, as the website will be hosted in our server.
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Dear Team,
# We have following two requirements from our reputed clients
# 1.	Development of new static web site for their IT division. The client would like to show case various products and service they offer and also various agencies their represents.
#
# The website will have approximately 15 web pages, but since the client have not decided on the content ; we need to suggest appropriate contents after referring www.bahwanit.com website as recommended by them. The site will include a page for user registration and based on the user email id collected , system will send the news letters as and when required.
# Since the division is a new set-up, they would also like to have the designing of their company logo.
#
#
# Please send us the best quote for development and hosting of the website along with 3 sample designs/templates or 3 reference web-sites at the earliest.
#
# 2.	Development of Corporate website for a big conglomerate with 75 plus group companies . The website will have approximately 100 web-pages that will display listing of all the group companies , agencies the group represents, about us, their vision and mission, NEWS, Careers, contact us. One page will be dedicated for each company.
#
#
# Please send us the best quote for development this website along with 3 sample designs/templates or 3 reference web-sites at the earliest.
#
# Both the above website should have the following features
# 1.	User should be able to modify the content using content management
# 2.	Should be responsive website
# 3.	Should be SEO friendly.
# Please send me your quote on vipul_mistry@yahoo.com . You can reach me on +968-92802178
#
# ----------------------
# Prediction: enquiry
# ----------------------
# i am web designer i need to job
# ----------------------
# Prediction: job
# ----------------------
# Hi,
# I'm looking for a job opportunity in your company. If there is any vacancy for B.E. fresher then please contact me.
# Thank you
# ----------------------
# Prediction: job
# ----------------------
#
#
# Hello.
#
# I am looking to have a website made. I have aquired the domain name already.
#
# I am looking for a website to which has 2 types of members.
#
# 1.Vip
# 2.Users.
#
# Vips will upload content such as pictures and videos. They will set there monthly subscription fee min 5 max 50.
#
# Uploading can be done in bulk pictures go to pictures section and videos go to videos section and posts can remain together but users can search through videos or pictures and also see all the vips posts.
#
# Vips can list items they have for sale on a shop section on the website.
#
# Vips connect there account to their own twitter account and a tweet will be sent out when they upload new content.
#
# Vips can also live stream and set a payperview price or leave it free of which the site gets 20%
#
# Users will pay to subscribe to vips as many as they choose they can only see content uploaded by those they have subscribed to.
#
# The site itself needs to be user friendly. The site will take 20% of subscriptions and purchases.
#
# Shop section where vips can list items they have for sale.
#
# I do have other requirements too if your quote is right I will be in contact with you and give you what remains to be done.
#
# Thank you.
#
#
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#      This is Sunaina. I am a MBA fresher and looking for a job opportunity in Digital marketing as i have done internship in that. If there is any vacancies in the same please let me know.
#
# Thankyou!
# ----------------------
# Prediction: job
# ----------------------
# Dear Mr./Mrs. Director,
#
# We are Czech company planned to build NEWS low-cost website made in Wordpress and we are searching for established serious web developer who can help us to meet this goal.
# Will you be so kind to send us your price quotation it?
# This request was sent to multiple developers as a form of competition, where we want to choose one, the most suitable Developer company that will offer us the most professional development at the lowest price.
# In return, we will offer to chosen developer also other projects in future.
#
# Approximate low-cost price will range from ₹ 30.000,00 to ₹ 40.000.00  (USD 400 – 600)
#
# REQUIREMENTS FOR DEVELOPMENT:
#
# -	WORDPRESS
# -	Logo, favicon, design UX, UI
# -	NEWS WEBSITE, Main pattern: www.idnes.cz and www.teraz.sk
# -	Languages: only one - Czech
# -	Highly Responsive Design
# -	Fully automated website with very fast response time to open an articles, videos, images
# -	No annual fees, only one-time paid solutions (except hosting and server paid by us)
# -	Desktop version 990-1170px and mobile version 320px wide
# -	1 home page + 8 subpages  (5-6 Categories)
# -	Advanced Fully-featured Content management system and Document management system
# -	Access – admin, limited access: sub-admin, publishers
# -	Ability for future Advertising management - google ads, banners ...
# -	Donation page with Payment gates: Paypal, Bank Cards, Transferwise
# -	Ability to manage and add any number of categories and articles
# -	Sorted and / or filtered by any field
# -	Automatically track new, hot, popular and editor’s picks articles
# -	Available Discussion under each Article and News, by subscribed users
# -	Share, Print & Rate option for articles
# -	Automatic tool for administrators to block inappropriate text from discussion boards like Akismet
# -	Cross Browser Optimization
# -	Quick and advanced search – hypertext, basic, advanced
# -	Advanced Tags, tags search, Cookies
# -	Integrated photo gallery
# -	Very Easy Video uploading & streaming
# -	Extremely simple and fast system for inserting and publishing of news, articles, photos, videos
# -	Adjustable timer for publishing of inserted news/articles
# -	Database of all articles
# -	Automated resizing of inserted photos
# -	Frequent news updates
# -	Monitoring of traffic
# -	Zoom in and Zoom out – articles
# -	Possible Sharing articles on social networks - buttons
# -	Automatic + Admin blocking of users – discussers, chatters, bloggers
# -	Support for RSS feeds
# -	Advanced SEO Optimization, High Security of website
# -	Setting Server and C-panel
#        -     Admin training After completion + 1 year maintenance/supervision and bug fixing
#
# We look forward to receive your answer with basic pricing quotation. In the case your price offer will attract us, we will send you more detailed description of functionalities and drafts of design.
# Feel free to ask any questions you may have!
#
# Kind regards,
#
# Eva Vargova (Ms)
# Assistant Manager
# Direct Media Team Czech Republic
# Email: project.directmedia@gmail.com
# SKYPE: Direct Media
# Tel: +420 607 338471
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Hello,
# I am interested in a website for my phone repair business. It would need to be a very professional, sleek, and simple design. My requirements are to have online payment, as well as integrated service booking system. Also, I already have hosting and domain so that is not needed. Let me know your best price and more information,
# Thank you.
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi,
#
# I was after some more information regarding outsourcing web development.
#
# Below are the requirements, can you please let me know if you can meet any or all of the below.
#
# -	We would supply the design and layout of the website and all design elements, so the developer would be strictly working on the development
# -	Development would need to be created on wordpress.
# -	I am looking for a company to work on our own test servers for the website.
# -	We do not require any domain/hosting or email setup.
#
# Do you have a price list or something I could look at also?
#
# ----------------------
# Prediction: enquiry
# ----------------------
# Hi ,
#
# There is a requirement from one of our client for new dynamic website.
#
# The requirement are as follows
#
#
# 	• Search within Site for brand, product (Good to have)
# 	• SEO
# 	• Enquiry Form. The user should be able to select the product/brand for the enquiry. System should send the acknowledgement mail to the User. Enquiry form should also capture key data elements like name, contact number and email
# 	• Chat option. Three user should be notified . Once any one user start the chat, other users should not be notified
# 	• Back-office module to update product/brand/images
# 	• Section A (refer the attached image) should contain banner
# 	• Section B (refer the attached image) should contain advertisement
# 	• Section C (refer the attached image) should display main content
# 	• Provision for the user to print the catalogue of a given product in pdf
# 	• Promotional mail should be sent to the users based on the email data bank . The email data can be captured through Enquiry form or should be uploaded from the excel file
# 	• The site should have option to navigate to Home / Products / Contact us (Enquiry)
# 	• System should be able to send promotional SMS
# 	• The site color theme should be navy blue and white
#
# Please send us your best time and cost estimates. The client would like to see the prototype.
# ----------------------
# Prediction: enquiry
# ----------------------
# hi sir my name is safal bhargav i am fresher i am applyiing for the jobe   i ahve good knowledge of web designing
# ----------------------
# Prediction: job
# ----------------------
# Hi,
#
# I am a co-founder of www.toplatest.com.
#
# I started this website with a company in UAE. This company didn't deliver exactly what I need.
#
# Therefore, here are my requirements:
#
# - Website modification (adding country and modifying layout, and other requirements to be discussed further).
# - make web crawlers work properly and accurately.
# - Add more merchants to crawl.
# - Marketing Campaign (next step after website and crawlers modifications)
#
# Waiting for your prompt reply.
#
# Thanks!
# Ibrahim
#
# ----------------------
# Prediction: enquiry
# ----------------------
# I want to apply for a job
# ----------------------
# Prediction: job
# ----------------------
# Hello there,
#
# I just check your website and it's interesting. Can you tell me more? Can we work together?
#
# I would like to inform you that I am a guest post service provider and a unique content writer.
#
# I have in my collection (700+)good quality sites. And I promise you I can successfully execute this job.
#
# Here are a few samples of our recent work:
#
# priceofbusiness.com/5-ways-to-improve-your-time-management-skills/
# bitrebels.com/business/6-press-release-writing-business/
# ceoworld.biz/2018/03/07/what-makes-an-innovative-leader/
# tgdaily.com/web/7-seo-tips-to-make-your-website-rank-higher-in-google-search
#
# All my sites are $40/post. I will charge extra only $15/500+ words unique article.It is very interesting I think. Kindly let me inform if you are interested.
# Waiting to hear back from you soon.
#
# Thanks.
# Debabrata Ruidas
# ----------------------
# Prediction: spam
# ----------------------
# Hello there,
#
# I would like to inform you that I am a guest post service provider and a unique content writer.
#
# I have in my collection (700+)good quality sites. And I promise you I can successfully execute this job.
#
# Here are a few samples of our recent work:
#
# Onestep4ward.com
# Travelwithbender.com
# Thehollywoodnews.com
# Homesthetics.net
# Justonewayticket.com
#
# All my sites are $40/post. I will charge extra only $15/500+ words unique article.It is very interesting I think. Kindly let me inform if you are interested.
# Waiting to hear back from you soon.
#
# Thanks.
# Sumella P.
# ----------------------
# Prediction: spam
# ----------------------
# 	Attention to CEO,
#
# 	I am Balvant Bathia, Business Development Executive from Visual InfoCraft, I would like to connect with you to share the proposal for remote work, especially for WordPress Development.
#
# 	We are proficient in HTML, CSS, PHP, and JavaScript. Furthermore, We use the most efficient web development tools to get our clients' job done in record time.
#
# 	My Website - http://visualinfocraft.com/
#
# 	To this end, We offer the below-listed services:
#
# 	1. WordPress Configuration
# 	2. Responsive Theme Design
# 	3. Plugin Development
# 	4. WooCommerce — setup, design, and development
# 	5. Mobile Optimization and...
# 	6. Troubleshooting
#
# 	We always try to keep the best code quality with bug-free, best app performance, and long term maintenance. We're always looking for a long-term partner who wants to make great success website development projects.
#
# 	We can design & develop websites and mobile applications for you(your clients) at the best competitive price, unbeatable quality, and on time.
#
# 	We used to charge $15 USD per hour and look forward to if we can be part of your development team.
#
# 	Let's have a brief conversation to explore a win-win business relationship. Appreciate your feedback, thanks.
#
# 	Thanks & Regards,
#
# 	Balvant Bathia
# 	Visual InfoCraft
# 	M: +91-93335 93330
# 	E: balvant@anilker.com
# 	S: bathia.balvant1
# 	W: www.visualinfocraft.com
# ----------------------
# Prediction: spam
# ----------------------
# For Flutter Developer job
# ----------------------
# Prediction: job
# ----------------------
# Looking for Freshers Job  Is any opening for freshers
# ----------------------
# Prediction: job
# ----------------------
# I have an MCA Students  And I interested for this job
# ----------------------
# Prediction: job
# ----------------------
# I m a Web designer and developer looking for a job in Web designing
# ----------------------
# Prediction: job
# ----------------------
# Hello I am Neeladri Mukherjee   B tech in Computer Science and Engineering looking for job as a software engineer software developer If there is any vacancy please let me know  Hope to hear from you soon   Thank you
# ----------------------
# Prediction: job
# ----------------------
# Job requirement
# ----------------------
# Prediction: job
# ----------------------
# I am MERN stack web developer looking for a job if there are any vacancy available for this profile please let me know  Thank you
# ----------------------
# Prediction: job
# ----------------------
# Hi   I am a professional full stack developer with 7   years experience in frontend   backend development  I have some skills in a wide variety of coding niches  from databases to graphic design and UI UX management in order to do job well     Here is a summary of the things that I may and will be able to do for you   - Core PHP  Laravel   - Git   Bitbucket        - NPM  Gulp  SCSS  - WordPress  Shopify  - Clickfunnel  Lightspeed  Webflow  - HTML5   CSS3  SCSS  - Bootstrap  Tailwind CSS  Foundation  - JS  javascript   jQuery   - PSD Sketch AI to HTML WordPress  - WordPress Theme Development  - WordPress Plugin Development  - API integrations with plugins and themes  - eCommerce Solutions   WooCommerce    Some of my work samples are   http   hbkhandev com     I look forward to discussing more of my expertise with you and see how we can potentially work together  I am available to speak with you anytime     Thank you
# ----------------------
# Prediction: job
# ----------------------
# I m Garima Chouhan  I m from Ratlam  I have completed MCA from Vellore institute of technology Bhopal  I m looking for backend developer job  I have knowledge about the programing languages like HTML CSS PHP JS
# ----------------------
# Prediction: job
# ----------------------
# Need a job
# ----------------------
# Prediction: job
# ----------------------
# I am looking for frontend developer internship/job
# ----------------------
# Prediction: job
# ----------------------
# i want a internship and as well as a job.
# ----------------------
# Prediction: job
# ----------------------
# Hi,
#
# My name is Liya C John and I am a QA Tester with 2 years of experience in Manual Testing. I’m writing this email in connection with a job opening I came across on your website.
#
# I have extensive hands-on expertise in manual, API, functional and regression testing on all projects and also build key test cases for performing manual and system integration testing in agile methodologies.
#
# I have attached a copy of my updated resume, please review it and call me at your convenience.
#
#
#
# Looking forward to connecting with you soon.
#
#
#
# Thanking you
# ----------------------
# Prediction: job
# ----------------------
# Dear Sir/Madam,
#
# I wish to apply for the position of frontend developer that is listed on your website. The role and the responsibilities listed in the job description match my interests and skills. I believe that I’m a good candidate for this position.
#
# If there is any requirment regarding this field give me a chance. I’m optimistic that you’ll consider me for this role. I look forward to hearing from you about this job opportunity.
#
# Sincerely,
# Avinash Kumar
# kumaravinash1998@gmail.com
# 8287562245
# ----------------------
# Prediction: job
# ----------------------
# Good day,
#
# My name is Eric and unlike a lot of emails you might get, I wanted to instead provide you with a word of encouragement – Congratulations
#
# What for?
#
# Part of my job is to check out websites and the work you’ve done with foduu.com definitely stands out.
#
# It’s clear you took building a website seriously and made a real investment of time and resources into making it top quality.
#
# There is, however, a catch… more accurately, a question…
#
# So when someone like me happens to find your site – maybe at the top of the search results (nice job BTW) or just through a random link, how do you know?
#
# More importantly, how do you make a connection with that person?
#
# Studies show that 7 out of 10 visitors don’t stick around – they’re there one second and then gone with the wind.
#
# Here’s a way to create INSTANT engagement that you may not have known about…
#
# Talk With Web Visitor is a software widget that’s works on your site, ready to capture any visitor’s Name, Email address and Phone Number.  It lets you know INSTANTLY that they’re interested – so that you can talk to that lead while they’re literally checking out foduu.com.
#
# CLICK HERE https://boostleadgeneration.com to try out a Live Demo with Talk With Web Visitor now to see exactly how it works.
#
# It could be a game-changer for your business – and it gets even better… once you’ve captured their phone number, with our new SMS Text With Lead feature, you can automatically start a text (SMS) conversation – immediately (and there’s literally a 100X difference between contacting someone within 5 minutes versus 30 minutes.)
#
# Plus then, even if you don’t close a deal right away, you can connect later on with text messages for new offers, content links, even just follow up notes to build a relationship.
#
# Everything I’ve just described is simple, easy, and effective.
#
# CLICK HERE https://boostleadgeneration.com to discover what Talk With Web Visitor can do for your business.
#
# You could be converting up to 100X more leads today!
#
# Eric
# PS: Talk With Web Visitor offers a FREE 14 days trial – and it even includes International Long Distance Calling.
# You have customers waiting to talk with you right now… don’t keep them waiting.
# CLICK HERE https://boostleadgeneration.com to try Talk With Web Visitor now.
#
# If you'd like to unsubscribe click here http://boostleadgeneration.com/unsubscribe.aspx?d=foduu.com
# ----------------------
# Prediction: spam
# ----------------------
# Dear valued customer,
# Are you tired of struggling to make ends meet? Are you searching for ways to increase your income and achieve financial freedom? Look no further than Mary's System.
#
# Mary's System is a comprehensive guide that teaches you how to boost your income and make money from home. From working as a virtual assistant to making money through online advertising, the guide covers a wide range of ways to increase your income. You also have access to a community of like-minded individuals who are also looking to achieve financial freedom.
#
# Start making money - http://bit.ly/3XUkonG
#
# But don't just take our word for it. Here's what one of our satisfied customers had to say:
#
# "I was a single mother struggling to make ends meet. I came across Mary's System and decided to give it a try. I was able to quit my job and work from home thanks to the system. I doubled my income in just a few months and now have the freedom to spend more time with my family. I highly recommend Mary's System to anyone looking to boost their income."
#
# But we understand that you might have doubts, that's why we want to invite you to try our system with a 30 day money back guarantee. If you don't see results we will give your money back.
# Don't let another day go by struggling to make ends meet. Take the first step towards financial freedom with Mary's System. Don't hesitate and claim your spot today!
#
# Best regards
#
# The Mary's System Team
#
# Use this link http://bit.ly/3XUkonG
# ----------------------
# Prediction: spam
# ----------------------
# You've been searching for ways to increase your income and make money fast. You've tried it all - from virtual assistant jobs to investing in stocks, but nothing seems to be working. Then, you come across Mary's System and it promises to change your financial future. But as you dig deeper, you begin to question its legitimacy. Are the glowing reviews too good to be true? Is this just another scam? The answer to these questions and the secret to boosting your income is just one click away, but will you take the risk and find out? Don't miss out on the opportunity to increase your income from home today!
#
# As you continue to research Mary's System, you come across a testimonial from a single mother who was able to quit her job and work from home thanks to the system. She claims to have doubled her income in just a few months and now has the freedom to spend more time with her family. This piques your interest even more and you decide to give it a try.
#
# You sign up for the program and are immediately given access to a comprehensive guide on how to boost your income. From working as a virtual assistant to making money through online advertising, the guide covers a wide range of ways to make money from home. You also have access to a community of like-minded individuals who are also looking to increase
#
# Use this link http://bit.ly/3R0pxbA to get the offer.
# ----------------------
# Prediction: spam
# ----------------------
# Hi, kindly send me quotation for a website with the below features:
#
#
# Admin Features
# 1. Add/Edit/Delete – States, Cities
# 2. Add/Edit/Delete - Categories
# 3. Edit/View/Delete/Block Advertisers.
# 4. Edit/View/Delete/Block users.
# 5. Download all advertisers Data.
# 6. Download all users Data.
# 7. Payment history – Admin can view all the ad payment done by advertisers.
# 8. Can create multiple ad packages. Based on category.
# 9. Payment Gateway Integration.
# Employer Features
# 1. Signup / Login. (Email verification mandatory for Reg)
# 2. Mobile OTP verification – (SMS API integration)
# 3. Can Add/Edit/delete the Job ads. (Free & Premium)
# 4. Delete the account permanently.
# Employee Features
# 1. Employee Reg/Login (Email verification mandatory for Reg)
# 2. Mobile OTP verification – (SMS API integration)
# 3. Can Add/Edit/delete the Resumes. (Free & Premium)
# 4. Delete the account permanently.
# 5. Employee can apply the job.
# Web Features
# 1. Ads will be displayed based on particular Country/state specific.
# 2. Terms & Condition.
# 3. Privacy Policy.
# 4. Payment Gateway Integration (Client should provide the API)
# 5. SMS gateway integration (Client should provide the API)
# 6. Contact Us.
# ----------------------
# Prediction: enquiry
# ----------------------
# I am looking for a job in web development and designing
# ----------------------
# Prediction: job
# ----------------------
# Website for small non-profit. We already have the domain name through Wordpress. There will be 5 pages. Eventually I would like to add a Spanish translation, which I can do myself.
#
# Home
# About Us
# Projects
# Get Involved
# Contact Us
#
# I would like to be able to edit the site for content.
#
# We do not need anything very fancy just a professional look. As a non-profit, we are looking for a professional but affordable job.
#
# Skype id: xiedailong17
# ----------------------
# Prediction: enquiry
# ----------------------
# plz contact me for job in php web developer post . I am 8month experience in this field.
# ----------------------
# Prediction: job
# ----------------------
# I am a fresher graduated from Indore institute of science and technology looking for job/internship opportunities in your prestigious and well known organization.
# My USP is that I am a fresher and I can be moulded as per company's requirement and will prove to be a valuable asset by hardwork and dedication.
# Please contact me if any available positions are present as this time.
# Thank you.
# Hope to hear from you soon.
#
# ----------------------
# Prediction: job
# ----------------------
# hiiiiiii
# mem ,
# i am fresher and searching a job in seo field.if your requirment then call me.
#
# thanks
# ----------------------
# Prediction: job
# ----------------------
# hello i am ashish jain looking for job.
# ----------------------
# Prediction: job
# ----------------------
# Pls sent me quotation for below application
# Customer should able to check and book service online, so they should able to check man power availability near to their location (15KM radious), once booking done by customer, application need to sent notification to all available man power for confirmation, once confirmation done, application need to notify customer for payment (I need payment gateway to be added to this application). On top of this I need admin user access and vendor user access... As Admin user access I should able to see all registered man power, schedule, booking and payment details, fail booking due to no manpower available (all this should be in simple report format) for vendor user access, they should able to see booking schedule and completed job details and pending payment. Once we have your quotation than I will get my IT team to discuss on details in IT language. Thanks
# ----------------------
# Prediction: enquiry
# ----------------------
# Looking for job in web designing
# ----------------------
# Prediction: job
# ----------------------
# Hello
# I'm a BE student in Computer Science field from Medi-Caps University, Indore. I love to do Graphic Designing and Web Designing and Development. I have already done a lot of work in this field and want to get some industry exposure.
# I got to know about your company while I was exploring the net. I am keen to know if you hire students for part time job in either Graphic Design or Web.
#
# Thank you
# ----------------------
# Prediction: job
# ----------------------
# We offer following Softwares with full source code Very Low cost than what it might be in house:
#
# Pricing per software : Rs.6,000/- onwards
# *  Android Applications
# *  Automobile Management
# *  Auto Clicks
# *  Ad Posting
# *  Book Shop Mgmt Software
# *  Boutique Management Software
# *  BUS BOOKING Management
# *  Bulk Email
# *  Bulk SMS
# *  Chitfund Software s
# *  Clinic Management Software
# *  Clone Websites
# *  College Management Software
# *  COLOUR LAB Management
# *  Dental Clinic Management
# *  Directory Script
# *  Doctors Management
# *  Ecommerce
# *  Exam Management
# *  Gym Management Software
# *  Hardware Shop Mgmt Software
# *  Hospital Management Software
# *  Hotel Management Software
# *  Institute Management Software
# *  InVentory Software
# *  Job Management
# *  Leads Management
# *  Lodge Management System
# *  MLM - Binary
# *  MLM- Unique
# *  MLM-Matrix
# *  MLM-Realestate
# *  MLM- Generation
# *  MLM-Helping
# *  MLM-Discount
# *  MLM- Level
# *  MLM- Australian Binary & other plans
# *  Online Exam
# *  Pathology Lab
# *  Pay per click
# *  pay per View
# *  Pay per reading Mail
# *  Pharmacy
# *  Property Management
# *  Project Managment
# *  Restaurant Software
# *  School Management System
# *  School SMS Management
# *  Stock Management Management
# * Steel /Cement Shop Software
#
# for demo kindly call - 098537 19337
#
# Whatsapp- 76840 53514
# ----------------------
# Prediction: spam
# ----------------------
# Hi,
#
# I am Syed Siddiq based in Dubai, UAE. I am looking for a Professional Web Designer & Developer who has a company, so that we collaborate and work as partners. I have good client base here in Dubai and had staff who were working with me but as you know the cost of leaving is v high here, so could not afford them  and they left me after getting good jobs. Right now working with freelancers who are not delivering me on time & at times making clients unhappy.  I want to work with you & will give you work and in return you have to give me at best rates. I am giving websites at afforable price & still want to reduce cost & give best services. Waiting for your reply.
#
# Thanks & Warm Regards,
# ----------------------
# Prediction: enquiry
# ----------------------
